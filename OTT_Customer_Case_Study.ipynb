# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Hepin.Sakariya\Downloads\customer_churn_data.csv")

# %%
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
df.nunique()
# Out:
# year                         1
# customer_id               1999
# phone_no                  2000
# gender                       2
# age                         63
# no_of_days_subscribed      204
# multi_screen                 2
# mail_subscribed              2
# weekly_mins_watched       1260
# minimum_daily_mins         149
# maximum_daily_mins        1260
# weekly_max_night_mins      111
# videos_watched              19
# maximum_days_inactive        7
# customer_support_calls      10
# churn                        2
# dtype: int64

# %%
df.describe()
# Out:
#          year    customer_id         age  no_of_days_subscribed  \
# count  2000.0    2000.000000  2000.00000            2000.000000
# mean   2015.0  554887.157500    38.69050              99.750000
# std       0.0  261033.690318    10.20641              39.755386
# min    2015.0  100198.000000    18.00000               1.000000
# 25%    2015.0  328634.750000    32.00000              73.000000
# 50%    2015.0  567957.500000    37.00000              99.000000
# 75%    2015.0  773280.250000    44.00000             127.000000
# max    2015.0  999961.000000    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# std              80.551627            2.785519            9.129165
# min               0.000000            0.000000            0.000000
# ...

# %%
df["year"]=df["year"].astype('datetime64[ns]')

# %%
df["customer_id"]=df["customer_id"].astype(object)

# %%
df["gender"]=df["gender"].astype('category')

# %%
df["churn"]=df["churn"].map({0.0:"Subscribed",1.0:"Un-Subscribed"})

# %%
df["multi_screen"]=df["multi_screen"].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   datetime64[ns]
#  1   customer_id             2000 non-null   object
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   category
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   category
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
df.describe()
# Out:
#                                 year         age  no_of_days_subscribed  \
# count                           2000  2000.00000            2000.000000
# mean   1970-01-01 00:00:00.000002015    38.69050              99.750000
# min    1970-01-01 00:00:00.000002015    18.00000               1.000000
# 25%    1970-01-01 00:00:00.000002015    32.00000              73.000000
# 50%    1970-01-01 00:00:00.000002015    37.00000              99.000000
# 75%    1970-01-01 00:00:00.000002015    44.00000             127.000000
# max    1970-01-01 00:00:00.000002015    82.00000             243.000000
# std                              NaN    10.20641              39.755386
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# min               0.000000            0.000000            0.000000
# ...

# %%
df1=df.drop("year",axis=1) # std is NaN

# %%
df1.isnull().sum()
# Out:
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %% [markdown]
# # Age Distribution

# %%
sns.displot(x="age",data=df1,bins=9,col="gender",hue="churn",element="step")
plt.show()
# Out:
# C:\Users\Hepin.Sakariya\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(x="minimum_daily_mins",y="maximum_daily_mins",data=df1,hue="gender",palette="husl")
# Out:
# C:\Users\Hepin.Sakariya\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.scatter(x="minimum_daily_mins",y="no_of_days_subscribed",data=df1,c="no_of_days_subscribed"
            ,s="no_of_days_subscribed",cmap="magma",alpha=0.7)
plt.xlabel("minimum_daily_mins")
plt.ylabel("no_of_days_subscribed")

plt.grid(linestyle=":")

# %%
sns.kdeplot(x="videos_watched",data=df1,hue="multi_screen",fill=True)
plt.grid(linestyle=":",color="green")
plt.show()

# %%
sns.countplot(x="gender",data=df1,hue="churn",palette="Spectral")
plt.grid(linestyle=":",color="green")

# %%
sns.stripplot(x="gender",y="no_of_days_subscribed",data=df1,hue="multi_screen",color="r",marker="o",size=3,legend="brief")
plt.grid(linestyle=":",color="orange")
# Out:
# C:\Users\Hepin.Sakariya\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:r'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(y="no_of_days_subscribed",x="age",data=df1,color="g",kind="hex")
plt.grid(linestyle=":",color="g")

# %%
sns.pairplot(df1,vars=["weekly_mins_watched","weekly_max_night_mins"],hue="gender",palette=["orange","green"])
# Out:
# C:\Users\Hepin.Sakariya\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
